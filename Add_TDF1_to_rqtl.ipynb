# %% [markdown]
# Author: Dan Shea
# Date: 2020.01.10
# Description: Add the TDF1 genotype to the existing rqtl.csv data set and re-run the linkage analysis

# %%
# The TDF1 genotyping (absence/presence)
tdf1 = ['A', 'A', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'A', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'A', 'A',
        'A', 'H', 'A', 'H', 'A', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H',
        'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'A', 'A', 'H', 'H', 'A', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H',
        'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'A', 'A', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H',
        'H', 'H', 'H', 'H', 'H', 'H', 'A', 'H', 'H', 'A', 'H', 'H', 'H',]

# %%
# TDF1 was present in PU and is deleted in AK plants
# So we don't need to re-code the calls as present is Heterozygous (H) and absence (A) is Homozygous for the (A) parent.
samples = ['L6', 'L7', 'L8', 'L9', 'L10', 'L11', 'L12', 'L13', 'L14', 'L15', 'L16', 'L17', 'L18', 'L19', 'L20', 'L21', 'L22', 'L23', 'L24', 'L25',
           'L26', 'L27', 'L28', 'L29', 'L30', 'L31', 'L32', 'L33', 'L34', 'L35', 'L36', 'L37', 'L38', 'L39', 'L40', 'L41', 'L42', 'L44', 'L45', 'L46',
           'L47', 'L48', 'L49', 'L50', 'L51', 'L52', 'L53', 'L54', 'L55', 'L56', 'L57', 'L58', 'L59', 'L60', 'L61', 'L62', 'L63', 'L64', 'L65', 'L66',
           'L67', 'L68', 'L70', 'L71', 'L72', 'L73', 'L74', 'L76', 'L78', 'L79', 'L81', 'L82', 'L83', 'L84', 'L85', 'L87', 'L88', 'L89', 'L90', 'L91',
           'L92', 'L93', 'L94', 'L95', 'L96', 'L97', 'L99', 'L100', 'L101', 'L102', 'L104', 'L105', 'L106', 'L107', 'L108', 'L109', 'L111', 'L112', 'L113',
           'L114', 'L115', 'L116', 'L117', 'L118', 'L119', 'L120', 'L121', 'L122', 'L123', 'L124', 'L125', 'L126', 'L127', 'L128', 'L130', 'L131', 'L132',
           'L133', 'L134', 'L135', 'L136', 'L137', 'L138', 'L139', 'L140',]

# %%
genotypes = dict(zip(samples, tdf1))

# %%
rqtl_file = 'rqtl.csv'

# %%
import pandas as pd

# %%
rqtl = pd.read_csv(rqtl_file)

# %%
rqtl[0:10]
# Out:
#     ID AMP0000011 AMP0000018 AMP0000020 AMP0000037 AMP0000052 AMP0000104  \
# 0  NaN          1          1          1          1          1          1
# 1   L6          H          H          H          A          H          H
# 2   L7          H          H          H          H          H          H
# 3   L8          A          H          H          A          H          H
# 4   L9          A          H          H          H          H          H
# 5  L10          H          A          B          H          H          H
# 6  L11          A          H          H          H          H          H
# 7  L12          H          H          H          H          H          H
# 8  L13          A          A          H          H          H          A
# 9  L14          H          H          B          H          H          H
#
#   AMP0000111 AMP0000116 AMP0000125  ... AMP0115950 AMP0115951 AMP0116104  \
# 0          1          1          1  ...          1          1          1
# ...

# %%
foo = [1] + tdf1
rqtl['TDF1'] = foo

# %%
rqtl
# Out:
#        ID AMP0000011 AMP0000018 AMP0000020 AMP0000037 AMP0000052 AMP0000104  \
# 0     NaN          1          1          1          1          1          1
# 1      L6          H          H          H          A          H          H
# 2      L7          H          H          H          H          H          H
# 3      L8          A          H          H          A          H          H
# 4      L9          A          H          H          H          H          H
# ..    ...        ...        ...        ...        ...        ...        ...
# 121  L136          H          A          H          H          H          H
# 122  L137          H          H          H          H          H          H
# 123  L138          H          A          H          H          H          A
# 124  L139          H          A          H          H          H          H
# 125  L140          A          H          H          H          H          A
#
# ...

# %%
rqtl.to_csv('rqtl_tdf1.csv', index=False)
